# %%
import numpy as np
import cv2
import random
import os

# %%
path = r"E:\Users\Morgan\Doccuments\UniMLProject\raw_datasets\WIDER_val\wider_face_val_bbx_gt.txt"
path_to_wider_imgs = r"E:\Users\Morgan\Doccuments\UniMLProject\raw_datasets\WIDER_val\images"

# %%
def get_training_data(path):
    '''Returns two lists: a list of the names of the image files and a list of the bounding boxes'''
    #Open file
    f = open(path,'r') 
    file = f.readlines()
    name = []
    box = []
    count = 0
    for i in file: 
        #Grab the files with only 1 face
        if i == '1\n':
            filename = file[count-1]
            bb = file[count+1]
        
            #Get rid of the /n
            filename = filename[:-1]
            #Convert into array of integer coordinates
            num = bb.split(' ')
            num = num[:4]
            num = [int(i) for i in num]
            
            #Save into array
            name.append(filename)
            box.append(num)
        count = count+1
    return name, box

# %%
def delete_zeros(name, box):
    '''Gets rid of errors in which bounding box coordinates are 0'''
    error=[]
    c=0
    for b in box:
        if b==[0,0,0,0]:
            error.append(c)
        c=c+1
    for e in error:
        del box[e]
        del name[e]
    return name, box

# %%
def save_coordinates(coordinates):
    '''Saves bounding box coordinates in txt file'''
    F = open('./coordinates.txt','w')
    for line in coordinates:
        line=line+'\n'
        F.write(line)

# %%
def create_scales(box):
    '''Create a list of scales that result in the face being 7,8,9,10,11,and 12 pixels big'''
    scale = np.empty([6])
    facesize = [12,11,10,9,8,7]
    width = box[2]
    height = box[3]
    larger = max(height, width)
    scale = [larger/i for i in facesize]
    return scale

# %%
def scale_image(image,scale):
    '''Scales image given the scale'''
    height, width, _ = image.shape
    width_scaled = int(np.ceil(width / scale))
    height_scaled = int(np.ceil(height / scale))
    im_data = cv2.resize(image, (width_scaled, height_scaled), interpolation=cv2.INTER_AREA)
    return im_data

# %%
def scale_box(box,scale):
    '''Scales bounding box given the scale'''
    box = [int(i/scale) for i in box]
    return box

# %%
def gen_pos_training(name, bbox, count):
    '''Generates 12x12 pixel images with faces. This probably could have been written more concisely...but oh well, here it is'''
    image = cv2.imread("./raw_datasets/WIDER_val/images/"+name)
    scales=create_scales(bbox)
    print(scales)
    bbox = [bbox[0],bbox[1],bbox[0]+bbox[2],bbox[1]+bbox[3]]
    coordinates = []
    
    #Scale to 12
    img=scale_image(image,scales[0])
    box = scale_box(bbox,scales[0])
    #If height > width
    if box[3]-box[1] >= box[2]-box[0]:
        x=box[2]-12
        y=box[3]-12
        while x<=box[0]:
            crop_img = img[y:y+12,x:x+12]
            if crop_img.shape == (12,12,3):
                cv2.imwrite(f'./pos_train/{count}.bmp',crop_img)
                newboxA=[box[0]-x,box[1]-y,box[2]-x,box[3]-y]
                newboxB=[i/12 for i in newboxA]
                coordinates.append(f'{count}.bmp: [{newboxB[0]},{newboxB[1]},{newboxB[2]},{newboxB[3]}]')
                count = count+1
            x = x+1
    #If width > height
    elif bbox[3]-bbox[1] <= bbox[2]-bbox[0]:
        x=bbox[2]-12
        y=bbox[3]-12
        while y<=bbox[1]:
            crop_img = img[y:y+12,x:x+12]
            if crop_img.shape == (12,12,3):
                cv2.imwrite(f'./pos_train/{count}.bmp',crop_img)
                newboxA=[box[0]-x,box[1]-y,box[2]-x,box[3]-y]
                newboxB=[i/12 for i in newboxA]
                coordinates.append(f'{count}.bmp: [{newboxB[0]},{newboxB[1]},{newboxB[2]},{newboxB[3]}]')
                count = count+1
            y = y+1
    #If equal
    elif bbox[3]-bbox[1] == bbox[2]-bbox[0]:
        crop_img = img[bbox[1]:bbox[3],box[1]:bbox[2]]
        cv2.imwrite(f'./pos_train/{count}.bmp',crop_img)
        coordinates.append(f'./pos_train/{count}.bmp: [0,0,1,1]')
        count = count+1
    
    #Scale to 11
    img=scale_image(image,scales[1])
    box = scale_box(bbox,scales[1])
    #If height > width
    if box[3]-box[1] > box[2]-box[0]:
        x=box[2]-12
        y=box[3]-12
        while x<=box[0]:
            crop_img = img[y:y+12,x:x+12]
            if crop_img.shape == (12,12,3):
                cv2.imwrite(f'./pos_train/{count}.bmp',crop_img)
                newboxA=[box[0]-x,box[1]-y,box[2]-x,box[3]-y]
                newboxB=[i/12 for i in newboxA]
                coordinates.append(f'{count}.bmp: [{newboxB[0]},{newboxB[1]},{newboxB[2]},{newboxB[3]}]')
                count = count+1
            x = x+1
        x=box[2]-12
        y=box[3]-11
        while x<=box[0]:
            crop_img = img[y:y+12,x:x+12]
            if crop_img.shape == (12,12,3):
                cv2.imwrite(f'./pos_train/{count}.bmp',crop_img)
                newboxA=[box[0]-x,box[1]-y,box[2]-x,box[3]-y]
                newboxB=[i/12 for i in newboxA]
                coordinates.append(f'{count}.bmp: [{newboxB[0]},{newboxB[1]},{newboxB[2]},{newboxB[3]}]')
                count = count+1
            x = x+1
    #If width > height
    elif bbox[3]-bbox[1] < bbox[2]-bbox[0]:
        x=bbox[2]-12
        y=bbox[3]-12
        while y<=bbox[1]:
            crop_img = img[y:y+12,x:x+12]
            if crop_img.shape == (12,12,3):
                cv2.imwrite(f'./pos_train/{count}.bmp',crop_img)
                newboxA=[box[0]-x,box[1]-y,box[2]-x,box[3]-y]
                newboxB=[i/12 for i in newboxA]
                coordinates.append(f'{count}.bmp: [{newboxB[0]},{newboxB[1]},{newboxB[2]},{newboxB[3]}]')
                count = count+1
            y = y+1
        x=bbox[2]-11
        y=bbox[3]-12
        while y<=bbox[1]:
            crop_img = img[y:y+12,x:x+12]
            if crop_img.shape == (12,12,3):
                cv2.imwrite(f'./pos_train/{count}.bmp',crop_img)
                newboxA=[box[0]-x,box[1]-y,box[2]-x,box[3]-y]
                newboxB=[i/12 for i in newboxA]
                coordinates.append(f'{count}.bmp: [{newboxB[0]},{newboxB[1]},{newboxB[2]},{newboxB[3]}]')
                count = count+1
            y = y+1
    #If equal
    elif bbox[3]-bbox[1] == bbox[2]-bbox[0]:
        x=bbox[2]-12
        y=bbox[3]-12
        while y<=bbox[1]:
            crop_img = img[y:y+12,x:x+12]
            if crop_img.shape == (12,12,3):
                cv2.imwrite(f'./pos_train/{count}.bmp',crop_img)
                newboxA=[box[0]-x,box[1]-y,box[2]-x,box[3]-y]
                newboxB=[i/12 for i in newboxA]
                coordinates.append(f'{count}.bmp: [{newboxB[0]},{newboxB[1]},{newboxB[2]},{newboxB[3]}]')
                count = count+1
            y = y+1
        x=bbox[2]-12
        y=bbox[3]-12
        while x<=bbox[0]:
            crop_img = img[y:y+12,x:x+12]
            if crop_img.shape == (12,12,3):
                cv2.imwrite(f'./pos_train/{count}.bmp',crop_img)
                newboxA=[box[0]-x,box[1]-y,box[2]-x,box[3]-y]
                newboxB=[i/12 for i in newboxA]
                coordinates.append(f'{count}.bmp: [{newboxB[0]},{newboxB[1]},{newboxB[2]},{newboxB[3]}]')
                count = count+1
            x = x+1
    
    #Scale to 10
    img=scale_image(image,scales[2])
    box = scale_box(bbox,scales[2])
    #If height > width
    if box[3]-box[1] > box[2]-box[0]:
        x=box[2]-12
        y=box[3]-12
        while x<=box[0]:
            crop_img = img[y:y+12,x:x+12]
            if crop_img.shape == (12,12,3):
                cv2.imwrite(f'./pos_train/{count}.bmp',crop_img)
                newboxA=[box[0]-x,box[1]-y,box[2]-x,box[3]-y]
                newboxB=[i/12 for i in newboxA]
                coordinates.append(f'{count}.bmp: [{newboxB[0]},{newboxB[1]},{newboxB[2]},{newboxB[3]}]')
                count = count+1
            x = x+1
        x=box[2]-12
        y=box[3]-11
        while x<=box[0]:
            crop_img = img[y:y+12,x:x+12]
            if crop_img.shape == (12,12,3):
                cv2.imwrite(f'./pos_train/{count}.bmp',crop_img)
                newboxA=[box[0]-x,box[1]-y,box[2]-x,box[3]-y]
                newboxB=[i/12 for i in newboxA]
                coordinates.append(f'{count}.bmp: [{newboxB[0]},{newboxB[1]},{newboxB[2]},{newboxB[3]}]')
                count = count+1
            x = x+1
        x=box[2]-12
        y=box[3]-10
        while x<=box[0]:
            crop_img = img[y:y+12,x:x+12]
            if crop_img.shape == (12,12,3):
                cv2.imwrite(f'./pos_train/{count}.bmp',crop_img)
                newboxA=[box[0]-x,box[1]-y,box[2]-x,box[3]-y]
                newboxB=[i/12 for i in newboxA]
                coordinates.append(f'{count}.bmp: [{newboxB[0]},{newboxB[1]},{newboxB[2]},{newboxB[3]}]')
                count = count+1
            x = x+1
    #If width > height
    elif bbox[3]-bbox[1] < bbox[2]-bbox[0]:
        x=bbox[2]-12
        y=bbox[3]-12
        while y<=bbox[1]:
            crop_img = img[y:y+12,x:x+12]
            if crop_img.shape == (12,12,3):
                cv2.imwrite(f'./pos_train/{count}.bmp',crop_img)
                newboxA=[box[0]-x,box[1]-y,box[2]-x,box[3]-y]
                newboxB=[i/12 for i in newboxA]
                coordinates.append(f'{count}.bmp: [{newboxB[0]},{newboxB[1]},{newboxB[2]},{newboxB[3]}]')
                count = count+1
            y = y+1
        x=bbox[2]-11
        y=bbox[3]-12
        while y<=bbox[1]:
            crop_img = img[y:y+12,x:x+12]
            if crop_img.shape == (12,12,3):
                cv2.imwrite(f'./pos_train/{count}.bmp',crop_img)
                newboxA=[box[0]-x,box[1]-y,box[2]-x,box[3]-y]
                newboxB=[i/12 for i in newboxA]
                coordinates.append(f'{count}.bmp: [{newboxB[0]},{newboxB[1]},{newboxB[2]},{newboxB[3]}]')
                count = count+1
            y = y+1
        x=bbox[2]-10
        y=bbox[3]-12
        while y<=bbox[1]:
            crop_img = img[y:y+12,x:x+12]
            if crop_img.shape == (12,12,3):
                cv2.imwrite(f'./pos_train/{count}.bmp',crop_img)
                newboxA=[box[0]-x,box[1]-y,box[2]-x,box[3]-y]
                newboxB=[i/12 for i in newboxA]
                coordinates.append(f'{count}.bmp: [{newboxB[0]},{newboxB[1]},{newboxB[2]},{newboxB[3]}]')
                count = count+1
            y = y+1
    #If equal
    elif bbox[3]-bbox[1] == bbox[2]-bbox[0]:
        x=bbox[2]-12
        y=bbox[3]-12
        while y<=bbox[1]:
            crop_img = img[y:y+12,x:x+12]
            if crop_img.shape == (12,12,3):
                cv2.imwrite(f'./pos_train/{count}.bmp',crop_img)
                newboxA=[box[0]-x,box[1]-y,box[2]-x,box[3]-y]
                newboxB=[i/12 for i in newboxA]
                coordinates.append(f'{count}.bmp: [{newboxB[0]},{newboxB[1]},{newboxB[2]},{newboxB[3]}]')
                count = count+1
            y = y+1
        x=bbox[2]-12
        y=bbox[3]-12
        while x<=bbox[0]:
            crop_img = img[y:y+12,x:x+12]
            if crop_img.shape == (12,12,3):
                cv2.imwrite(f'./pos_train/{count}.bmp',crop_img)
                newboxA=[box[0]-x,box[1]-y,box[2]-x,box[3]-y]
                newboxB=[i/12 for i in newboxA]
                coordinates.append(f'{count}.bmp: [{newboxB[0]},{newboxB[1]},{newboxB[2]},{newboxB[3]}]')
                count = count+1
            x = x+1
            
    #Scale to 9
    img=scale_image(image,scales[3])
    box = scale_box(bbox,scales[3])
    #If height > width
    if box[3]-box[1] > box[2]-box[0]:
        x=box[2]-12
        y=box[3]-12
        while x<=box[0]:
            crop_img = img[y:y+12,x:x+12]
            if crop_img.shape == (12,12,3):
                cv2.imwrite(f'./pos_train/{count}.bmp',crop_img)
                newboxA=[box[0]-x,box[1]-y,box[2]-x,box[3]-y]
                newboxB=[i/12 for i in newboxA]
                coordinates.append(f'{count}.bmp: [{newboxB[0]},{newboxB[1]},{newboxB[2]},{newboxB[3]}]')
                count = count+1
            x = x+1
        x=box[2]-12
        y=box[3]-11
        while x<=box[0]:
            crop_img = img[y:y+12,x:x+12]
            if crop_img.shape == (12,12,3):
                cv2.imwrite(f'./pos_train/{count}.bmp',crop_img)
                newboxA=[box[0]-x,box[1]-y,box[2]-x,box[3]-y]
                newboxB=[i/12 for i in newboxA]
                coordinates.append(f'{count}.bmp: [{newboxB[0]},{newboxB[1]},{newboxB[2]},{newboxB[3]}]')
                count = count+1
            x = x+1
        x=box[2]-12
        y=box[3]-10
        while x<=box[0]:
            crop_img = img[y:y+12,x:x+12]
            if crop_img.shape == (12,12,3):
                cv2.imwrite(f'./pos_train/{count}.bmp',crop_img)
                newboxA=[box[0]-x,box[1]-y,box[2]-x,box[3]-y]
                newboxB=[i/12 for i in newboxA]
                coordinates.append(f'{count}.bmp: [{newboxB[0]},{newboxB[1]},{newboxB[2]},{newboxB[3]}]')
                count = count+1
            x = x+1
        x=box[2]-12
        y=box[3]-9
        while x<=box[0]:
            crop_img = img[y:y+12,x:x+12]
            if crop_img.shape == (12,12,3):
                cv2.imwrite(f'./pos_train/{count}.bmp',crop_img)
                newboxA=[box[0]-x,box[1]-y,box[2]-x,box[3]-y]
                newboxB=[i/12 for i in newboxA]
                coordinates.append(f'{count}.bmp: [{newboxB[0]},{newboxB[1]},{newboxB[2]},{newboxB[3]}]')
                count = count+1
            x = x+1
    #If width > height
    elif bbox[3]-bbox[1] < bbox[2]-bbox[0]:
        x=bbox[2]-12
        y=bbox[3]-12
        while y<=bbox[1]:
            crop_img = img[y:y+12,x:x+12]
            if crop_img.shape == (12,12,3):
                cv2.imwrite(f'./pos_train/{count}.bmp',crop_img)
                newboxA=[box[0]-x,box[1]-y,box[2]-x,box[3]-y]
                newboxB=[i/12 for i in newboxA]
                coordinates.append(f'{count}.bmp: [{newboxB[0]},{newboxB[1]},{newboxB[2]},{newboxB[3]}]')
                count = count+1
            y = y+1
        x=bbox[2]-11
        y=bbox[3]-12
        while y<=bbox[1]:
            crop_img = img[y:y+12,x:x+12]
            if crop_img.shape == (12,12,3):
                cv2.imwrite(f'./pos_train/{count}.bmp',crop_img)
                newboxA=[box[0]-x,box[1]-y,box[2]-x,box[3]-y]
                newboxB=[i/12 for i in newboxA]
                coordinates.append(f'{count}.bmp: [{newboxB[0]},{newboxB[1]},{newboxB[2]},{newboxB[3]}]')
                count = count+1
            y = y+1
        x=bbox[2]-10
        y=bbox[3]-12
        while y<=bbox[1]:
            crop_img = img[y:y+12,x:x+12]
            if crop_img.shape == (12,12,3):
                cv2.imwrite(f'./pos_train/{count}.bmp',crop_img)
                newboxA=[box[0]-x,box[1]-y,box[2]-x,box[3]-y]
                newboxB=[i/12 for i in newboxA]
                coordinates.append(f'{count}.bmp: [{newboxB[0]},{newboxB[1]},{newboxB[2]},{newboxB[3]}]')
                count = count+1
            y = y+1
        x=bbox[2]-9
        y=bbox[3]-12
        while y<=bbox[1]:
            crop_img = img[y:y+12,x:x+12]
            if crop_img.shape == (12,12,3):
                cv2.imwrite(f'./pos_train/{count}.bmp',crop_img)
                newboxA=[box[0]-x,box[1]-y,box[2]-x,box[3]-y]
                newboxB=[i/12 for i in newboxA]
                coordinates.append(f'{count}.bmp: [{newboxB[0]},{newboxB[1]},{newboxB[2]},{newboxB[3]}]')
                count = count+1
            y = y+1
    #If equal
    elif bbox[3]-bbox[1] == bbox[2]-bbox[0]:
        x=bbox[2]-12
        y=bbox[3]-12
        while y<=bbox[1]:
            crop_img = img[y:y+12,x:x+12]
            if crop_img.shape == (12,12,3):
                cv2.imwrite(f'./pos_train/{count}.bmp',crop_img)
                newboxA=[box[0]-x,box[1]-y,box[2]-x,box[3]-y]
                newboxB=[i/12 for i in newboxA]
                coordinates.append(f'{count}.bmp: [{newboxB[0]},{newboxB[1]},{newboxB[2]},{newboxB[3]}]')
                count = count+1
            y = y+1
        x=bbox[2]-12
        y=bbox[3]-12
        while x<=bbox[0]:
            crop_img = img[y:y+12,x:x+12]
            if crop_img.shape == (12,12,3):
                cv2.imwrite(f'./pos_train/{count}.bmp',crop_img)
                newboxA=[box[0]-x,box[1]-y,box[2]-x,box[3]-y]
                newboxB=[i/12 for i in newboxA]
                coordinates.append(f'{count}.bmp: [{newboxB[0]},{newboxB[1]},{newboxB[2]},{newboxB[3]}]')
                count = count+1
            x = x+1
    return coordinates, count

# %%
def gen_neg_training(name, bbox, count):
    '''Generates 12x12 pixel images with no faces'''
    path =os.path.join("./raw_datasets/WIDER_val/images/",name)
    print(path)
    image = cv2.imread(path)
    scales=create_scales(bbox)
    print(scales)
    bbox = [bbox[0],bbox[1],bbox[0]+bbox[2],bbox[1]+bbox[3]]
    a = name.split('/')
    b = a[1][:-4]
    
    #For each scale:
    for j in range(4):
        img=scale_image(image,scales[j])
        box = scale_box(bbox,scales[j])
        height, width, _ = img.shape
        i=0
        y1=0
        if width<=13 or height<=13:
            i=16
        while i<15:
            x=random.randint(0,width-13)
            y=random.randint(0,height-13)
            if y1>100: #If something went wrong and it keeps on falling into "continue", just break out of the loop
                i=16
                break
            if [x,y]>[box[0]-12,box[1]-12] and [x,y]<[box[2],box[3]]: #If the 12x12 box overlaps with the bounding box, draw another box
                y1=y1+1
                continue
            else: #If it doesn't overlap, crop the image.
                crop_img = img[y:y+12,x:x+12]
                cv2.imwrite(f'./neg_train/{count}.bmp',crop_img)
                count = count+1
                i=i+1
    print("count",count)
    return count

# %%
name,box = get_training_data(path)
name,box = delete_zeros(name,box)

# %%
pcount=1
ncount=1
coordinateA=[]
for i in range(100):
    print(i)
    ncount = gen_neg_training(name[i],box[i],ncount)
    coordinateB, pcount = gen_pos_training(name[i],box[i],pcount)
    coordinateA=coordinateA+coordinateB
    print('ncount:',ncount)
    print('pcount:',pcount)
save_coordinates(coordinateA)
# Out:
# 0
# ./raw_datasets/WIDER_val/images/0--Parade/0_Parade_Parade_0_829.jpg
# [36.916666666666664, 40.27272727272727, 44.3, 49.22222222222222, 55.375, 63.285714285714285]
# count 3
# [36.916666666666664, 40.27272727272727, 44.3, 49.22222222222222, 55.375, 63.285714285714285]
# ncount: 3
# pcount: 67
# 1
# ./raw_datasets/WIDER_val/images/0--Parade/0_Parade_marchingband_1_818.jpg
# [46.083333333333336, 50.27272727272727, 55.3, 61.44444444444444, 69.125, 79.0]
# count 18
# [46.083333333333336, 50.27272727272727, 55.3, 61.44444444444444, 69.125, 79.0]
# ncount: 18
# pcount: 98
# 2
# ./raw_datasets/WIDER_val/images/0--Parade/0_Parade_Parade_0_246.jpg
# [49.166666666666664, 53.63636363636363, 59.0, 65.55555555555556, 73.75, 84.28571428571429]
# count 18
# [49.166666666666664, 53.63636363636363, 59.0, 65.55555555555556, 73.75, 84.28571428571429]
# ncount: 18
# pcount: 98
# 3
# ./raw_datasets/WIDER_val/images/0--Parade/0_Parade_marchingband_1_356.jpg
# [9.5, 10.363636363636363, 11.4, 12.666666666666666, 14.25, 16.285714285714285]
# count 78
# [9.5, 10.363636363636363, 11.4, 12.666666666666666, 14.25, 16.285714285714285]
# ncount: 78
# pcount: 98
# 4
# ./raw_datasets/WIDER_val/images/0--Parade/0_Parade_Parade_0_468.jpg
# [29.5, 32.18181818181818, 35.4, 39.333333333333336, 44.25, 50.57142857142857]
# count 94
# [29.5, 32.18181818181818, 35.4, 39.333333333333336, 44.25, 50.57142857142857]
# ncount: 94
# pcount: 149
# 5
# ./raw_datasets/WIDER_val/images/0--Parade/0_Parade_Parade_0_461.jpg
# [9.166666666666666, 10.0, 11.0, 12.222222222222221, 13.75, 15.714285714285714]
# count 154
# [9.166666666666666, 10.0, 11.0, 12.222222222222221, 13.75, 15.714285714285714]
# ncount: 154
# pcount: 197
# 6
# ./raw_datasets/WIDER_val/images/0--Parade/0_Parade_Parade_0_757.jpg
# [25.833333333333332, 28.181818181818183, 31.0, 34.44444444444444, 38.75, 44.285714285714285]
# count 214
# [25.833333333333332, 28.181818181818183, 31.0, 34.44444444444444, 38.75, 44.285714285714285]
# ncount: 214
# pcount: 240
# 7
# ./raw_datasets/WIDER_val/images/1--Handshaking/1_Handshaking_Handshaking_1_766.jpg
# [31.166666666666668, 34.0, 37.4, 41.55555555555556, 46.75, 53.42857142857143]
# count 220
# [31.166666666666668, 34.0, 37.4, 41.55555555555556, 46.75, 53.42857142857143]
# ncount: 220
# pcount: 294
# 8
# ./raw_datasets/WIDER_val/images/1--Handshaking/1_Handshaking_Handshaking_1_362.jpg
# [42.333333333333336, 46.18181818181818, 50.8, 56.44444444444444, 63.5, 72.57142857142857]
# count 220
# [42.333333333333336, 46.18181818181818, 50.8, 56.44444444444444, 63.5, 72.57142857142857]
# ncount: 220
# pcount: 299
# 9
# ./raw_datasets/WIDER_val/images/1--Handshaking/1_Handshaking_Handshaking_1_522.jpg
# [12.5, 13.636363636363637, 15.0, 16.666666666666668, 18.75, 21.428571428571427]
# count 280
# [12.5, 13.636363636363637, 15.0, 16.666666666666668, 18.75, 21.428571428571427]
# ncount: 280
# pcount: 351
# 10
# ./raw_datasets/WIDER_val/images/1--Handshaking/1_Handshaking_Handshaking_1_314.jpg
# [9.333333333333334, 10.181818181818182, 11.2, 12.444444444444445, 14.0, 16.0]
# count 340
# [9.333333333333334, 10.181818181818182, 11.2, 12.444444444444445, 14.0, 16.0]
# ncount: 340
# pcount: 414
# 11
# ./raw_datasets/WIDER_val/images/1--Handshaking/1_Handshaking_Handshaking_1_465.jpg
# [42.333333333333336, 46.18181818181818, 50.8, 56.44444444444444, 63.5, 72.57142857142857]
# count 340
# [42.333333333333336, 46.18181818181818, 50.8, 56.44444444444444, 63.5, 72.57142857142857]
# ncount: 340
# pcount: 459
# 12
# ./raw_datasets/WIDER_val/images/1--Handshaking/1_Handshaking_Handshaking_1_94.jpg
# [29.5, 32.18181818181818, 35.4, 39.333333333333336, 44.25, 50.57142857142857]
# count 356
# [29.5, 32.18181818181818, 35.4, 39.333333333333336, 44.25, 50.57142857142857]
# ncount: 356
# pcount: 520
# 13
# ./raw_datasets/WIDER_val/images/1--Handshaking/1_Handshaking_Handshaking_1_380.jpg
# [11.833333333333334, 12.909090909090908, 14.2, 15.777777777777779, 17.75, 20.285714285714285]
# count 416
# [11.833333333333334, 12.909090909090908, 14.2, 15.777777777777779, 17.75, 20.285714285714285]
# ncount: 416
# pcount: 520
# 14
# ./raw_datasets/WIDER_val/images/1--Handshaking/1_Handshaking_Handshaking_1_107.jpg
# [21.5, 23.454545454545453, 25.8, 28.666666666666668, 32.25, 36.857142857142854]
# count 476
# [21.5, 23.454545454545453, 25.8, 28.666666666666668, 32.25, 36.857142857142854]
# ncount: 476
# pcount: 584
# 15
# ./raw_datasets/WIDER_val/images/1--Handshaking/1_Handshaking_Handshaking_1_275.jpg
# [26.0, 28.363636363636363, 31.2, 34.666666666666664, 39.0, 44.57142857142857]
# count 511
# [26.0, 28.363636363636363, 31.2, 34.666666666666664, 39.0, 44.57142857142857]
# ncount: 511
# pcount: 644
# 16
# ./raw_datasets/WIDER_val/images/1--Handshaking/1_Handshaking_Handshaking_1_35.jpg
# [21.5, 23.454545454545453, 25.8, 28.666666666666668, 32.25, 36.857142857142854]
# count 571
# [21.5, 23.454545454545453, 25.8, 28.666666666666668, 32.25, 36.857142857142854]
# ncount: 571
# pcount: 700
# 17
# ./raw_datasets/WIDER_val/images/1--Handshaking/1_Handshaking_Handshaking_1_457.jpg
# [55.333333333333336, 60.36363636363637, 66.4, 73.77777777777777, 83.0, 94.85714285714286]
# count 571
# [55.333333333333336, 60.36363636363637, 66.4, 73.77777777777777, 83.0, 94.85714285714286]
# ncount: 571
# pcount: 718
# 18
# ./raw_datasets/WIDER_val/images/1--Handshaking/1_Handshaking_Handshaking_1_567.jpg
# [57.916666666666664, 63.18181818181818, 69.5, 77.22222222222223, 86.875, 99.28571428571429]
# count 571
# [57.916666666666664, 63.18181818181818, 69.5, 77.22222222222223, 86.875, 99.28571428571429]
# ncount: 571
# pcount: 751
# 19
# ./raw_datasets/WIDER_val/images/10--People_Marching/10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_938.jpg
# [13.0, 14.181818181818182, 15.6, 17.333333333333332, 19.5, 22.285714285714285]
# count 631
# [13.0, 14.181818181818182, 15.6, 17.333333333333332, 19.5, 22.285714285714285]
# ncount: 631
# pcount: 810
# 20
# ./raw_datasets/WIDER_val/images/10--People_Marching/10_People_Marching_People_Marching_2_316.jpg
# [18.333333333333332, 20.0, 22.0, 24.444444444444443, 27.5, 31.428571428571427]
# count 691
# [18.333333333333332, 20.0, 22.0, 24.444444444444443, 27.5, 31.428571428571427]
# ncount: 691
# pcount: 818
# 21
# ./raw_datasets/WIDER_val/images/10--People_Marching/10_People_Marching_People_Marching_2_934.jpg
# [12.666666666666666, 13.818181818181818, 15.2, 16.88888888888889, 19.0, 21.714285714285715]
# count 751
# [12.666666666666666, 13.818181818181818, 15.2, 16.88888888888889, 19.0, 21.714285714285715]
# ncount: 751
# pcount: 874
# 22
# ./raw_datasets/WIDER_val/images/10--People_Marching/10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_1020.jpg
# [4.083333333333333, 4.454545454545454, 4.9, 5.444444444444445, 6.125, 7.0]
# count 811
# [4.083333333333333, 4.454545454545454, 4.9, 5.444444444444445, 6.125, 7.0]
# ncount: 811
# pcount: 954
# 23
# ./raw_datasets/WIDER_val/images/10--People_Marching/10_People_Marching_People_Marching_2_496.jpg
# [11.0, 12.0, 13.2, 14.666666666666666, 16.5, 18.857142857142858]
# count 871
# [11.0, 12.0, 13.2, 14.666666666666666, 16.5, 18.857142857142858]
# ncount: 871
# pcount: 1022
# 24
# ./raw_datasets/WIDER_val/images/10--People_Marching/10_People_Marching_People_Marching_2_638.jpg
# [38.166666666666664, 41.63636363636363, 45.8, 50.888888888888886, 57.25, 65.42857142857143]
# count 871
# [38.166666666666664, 41.63636363636363, 45.8, 50.888888888888886, 57.25, 65.42857142857143]
# ncount: 871
# pcount: 1075
# 25
# ./raw_datasets/WIDER_val/images/10--People_Marching/10_People_Marching_People_Marching_2_236.jpg
# [2.3333333333333335, 2.5454545454545454, 2.8, 3.111111111111111, 3.5, 4.0]
# count 931
# [2.3333333333333335, 2.5454545454545454, 2.8, 3.111111111111111, 3.5, 4.0]
# ncount: 931
# pcount: 1115
# 26
# ./raw_datasets/WIDER_val/images/10--People_Marching/10_People_Marching_People_Marching_2_823.jpg
# [21.333333333333332, 23.272727272727273, 25.6, 28.444444444444443, 32.0, 36.57142857142857]
# count 991
# [21.333333333333332, 23.272727272727273, 25.6, 28.444444444444443, 32.0, 36.57142857142857]
# ncount: 991
# pcount: 1172
# 27
# ./raw_datasets/WIDER_val/images/10--People_Marching/10_People_Marching_People_Marching_10_People_Marching_People_Marching_10_552.jpg
# [6.333333333333333, 6.909090909090909, 7.6, 8.444444444444445, 9.5, 10.857142857142858]
# count 1051
# [6.333333333333333, 6.909090909090909, 7.6, 8.444444444444445, 9.5, 10.857142857142858]
# ncount: 1051
# pcount: 1218
# 28
# ./raw_datasets/WIDER_val/images/10--People_Marching/10_People_Marching_People_Marching_2_935.jpg
# [28.25, 30.818181818181817, 33.9, 37.666666666666664, 42.375, 48.42857142857143]
# count 1094
# [28.25, 30.818181818181817, 33.9, 37.666666666666664, 42.375, 48.42857142857143]
# ncount: 1094
# pcount: 1284
# 29
# ./raw_datasets/WIDER_val/images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_865.jpg
# [35.166666666666664, 38.36363636363637, 42.2, 46.888888888888886, 52.75, 60.285714285714285]
# count 1094
# [35.166666666666664, 38.36363636363637, 42.2, 46.888888888888886, 52.75, 60.285714285714285]
# ncount: 1094
# pcount: 1337
# 30
# ./raw_datasets/WIDER_val/images/11--Meeting/11_Meeting_Meeting_11_Meeting_Meeting_11_320.jpg
# [19.166666666666668, 20.90909090909091, 23.0, 25.555555555555557, 28.75, 32.857142857142854]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-534124d9d3c5> in <module>()
#       4 for i in range(100):
#       5     print(i)
# ----> 6     ncount = gen_neg_training(name[i],box[i],ncount)
#       7     coordinateB, pcount = gen_pos_training(name[i],box[i],pcount)
#       8     coordinateA=coordinateA+coordinateB
#
# <ipython-input-37-8b23d55a8ed0> in gen_neg_training(name, bbox, count)
#      30             else: #If it doesn't overlap, crop the image.
#      31                 crop_img = img[y:y+12,x:x+12]
# ---> 32                 cv2.imwrite(f'./neg_train/{count}.bmp',crop_img)
#      33                 count = count+1
#      34                 i=i+1
#
# KeyboardInterrupt:
